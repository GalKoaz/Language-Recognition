# %% [markdown]
# # **Model Version: 0.1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### ***Imports***

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
import os
import numpy as np
import librosa
import random
from torch.utils.data import DataLoader
from torch import optim
import argparse
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **Models**

# %%
class TDNN(nn.Module):
    
    def __init__(
                    self, 
                    input_dim=23, 
                    output_dim=512,
                    context_size=5,
                    stride=1,
                    dilation=1,
                    batch_norm=False,
                    dropout_p=0.2
                ):
        '''
        TDNN as defined by https://www.danielpovey.com/files/2015_interspeech_multisplice.pdf

        Affine transformation not applied globally to all frames but smaller windows with local context

        batch_norm: True to include batch normalisation after the non linearity
        
        Context size and dilation determine the frames selected
        (although context size is not really defined in the traditional sense)
        For example:
            context size 5 and dilation 1 is equivalent to [-2,-1,0,1,2]
            context size 3 and dilation 2 is equivalent to [-2, 0, 2]
            context size 1 and dilation 1 is equivalent to [0]
        '''
        super(TDNN, self).__init__()
        self.context_size = context_size
        self.stride = stride
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.dilation = dilation
        self.dropout_p = dropout_p
        self.batch_norm = batch_norm
      
        self.kernel = nn.Linear(input_dim*context_size, output_dim)
        self.nonlinearity = nn.ReLU()
        if self.batch_norm:
            self.bn = nn.BatchNorm1d(output_dim)
        if self.dropout_p:
            self.drop = nn.Dropout(p=self.dropout_p)
        
    def forward(self, x):
        '''
        input: size (batch, seq_len, input_features)
        outpu: size (batch, new_seq_len, output_features)
        '''
        
        _, _, d = x.shape
        assert (d == self.input_dim), 'Input dimension was wrong. Expected ({}), got ({})'.format(self.input_dim, d)
        x = x.unsqueeze(1)

        # Unfold input into smaller temporal contexts
        x = F.unfold(
                        x, 
                        (self.context_size, self.input_dim), 
                        stride=(1,self.input_dim), 
                        dilation=(self.dilation,1)
                    )

        # N, output_dim*context_size, new_t = x.shape
        x = x.transpose(1,2)
        x = self.kernel(x.float())
        x = self.nonlinearity(x)
        
        if self.dropout_p:
            x = self.drop(x)

        if self.batch_norm:
            x = x.transpose(1,2)
            x = self.bn(x)
            x = x.transpose(1,2)

        return x

# %%
class X_vector(nn.Module):
    def __init__(self, input_dim = 40, num_classes=10):
        super(X_vector, self).__init__()
        self.tdnn1 = TDNN(input_dim=input_dim, output_dim=1280, context_size=5, dilation=1,dropout_p=0.5)
        self.tdnn2 = TDNN(input_dim=1280, output_dim=1024, context_size=3, dilation=1,dropout_p=0.5)
        self.tdnn3 = TDNN(input_dim=1024, output_dim=768, context_size=2, dilation=2,dropout_p=0.5)
        self.tdnn4 = TDNN(input_dim=768, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn5 = TDNN(input_dim=512, output_dim=256, context_size=1, dilation=3,dropout_p=0.5)
        #### Frame levelPooling
        self.segment6 = nn.Linear(512, 512)
        self.segment7 = nn.Linear(512, 512)
        self.output = nn.Linear(512, num_classes)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, inputs):
        tdnn1_out = self.tdnn1(inputs)
        return tdnn1_out
        tdnn2_out = self.tdnn2(tdnn1_out)
        tdnn3_out = self.tdnn3(tdnn2_out)
        tdnn4_out = self.tdnn4(tdnn3_out)
        tdnn5_out = self.tdnn5(tdnn4_out)
        ### Stat Pool
        mean = torch.mean(tdnn5_out,1)
        std = torch.std(tdnn5_out,1)
        stat_pooling = torch.cat((mean,std),1)
        segment6_out = self.segment6(stat_pooling)
        x_vec = self.segment7(segment6_out)
        predictions = self.softmax(self.output(x_vec))
        return predictions,x_vec

# %%
class X_vector(nn.Module):
    def __init__(self, input_dim = 40, num_classes=10):
        super(X_vector, self).__init__()
        self.tdnn1 = TDNN(input_dim=input_dim, output_dim=1280, context_size=5, dilation=1,dropout_p=0.5)
        self.tdnn2 = TDNN(input_dim=1280, output_dim=1024, context_size=3, dilation=1,dropout_p=0.5)
        self.tdnn3 = TDNN(input_dim=1024, output_dim=768, context_size=2, dilation=2,dropout_p=0.5)
        self.tdnn4 = TDNN(input_dim=768, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn5 = TDNN(input_dim=512, output_dim=256, context_size=1, dilation=3,dropout_p=0.5)
        #### Frame levelPooling
        self.segment6 = nn.Linear(512, 512)
        self.segment7 = nn.Linear(512, 512)
        self.output = nn.Linear(512, num_classes)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, inputs):
        tdnn1_out = self.tdnn1(inputs)
        tdnn2_out = self.tdnn2(tdnn1_out)
        tdnn3_out = self.tdnn3(tdnn2_out)
        tdnn4_out = self.tdnn4(tdnn3_out)
        tdnn5_out = self.tdnn5(tdnn4_out)
        ### Stat Pool
        
        mean = torch.mean(tdnn5_out,1)
        std = torch.var(tdnn5_out,1)
        stat_pooling = torch.cat((mean,std),1)
        segment6_out = self.segment6(stat_pooling)
        x_vec = self.segment7(segment6_out)
        predictions = self.output(x_vec)
        return predictions,x_vec

# %% [markdown]
# ### Utiles

# %%
def load_wav(audio_filepath, sr, min_dur_sec=4):
    audio_data,fs  = librosa.load(audio_filepath,sr=16000)
    len_file = len(audio_data)
    
    if len_file <int(min_dur_sec*sr):
        dummy=np.zeros((1,int(min_dur_sec*sr)-len_file))
        extened_wav = np.concatenate((audio_data,dummy[0]))
    else:
        
        extened_wav = audio_data
    return extened_wav


def lin_mel_from_wav(wav, hop_length, win_length, n_mels):
    linear = librosa.feature.melspectrogram(wav, n_mels=n_mels, win_length=win_length, hop_length=hop_length) # linear spectrogram
    return linear.T

def lin_spectogram_from_wav(wav, hop_length, win_length, n_fft=512):
    linear = librosa.stft(wav, n_fft=n_fft, win_length=win_length, hop_length=hop_length) # linear spectrogram
    return linear.T


def feature_extraction(filepath,sr=16000, min_dur_sec=4,win_length=400,hop_length=160, n_mels=40, spec_len=400,mode='train'):
    audio_data = load_wav(filepath, sr=sr,min_dur_sec=min_dur_sec)
    linear_spect = lin_spectogram_from_wav(audio_data, hop_length, win_length, n_fft=512)
    mag, _ = librosa.magphase(linear_spect)  # magnitude
    mag_T = mag.T
    mu = np.mean(mag_T, 0, keepdims=True)
    std = np.std(mag_T, 0, keepdims=True)
    return (mag_T - mu) / (std + 1e-5)
    
    
    
    
def load_data(filepath,sr=16000, min_dur_sec=4,win_length=400,hop_length=160, n_mels=40, spec_len=400,mode='train'):
    audio_data = load_wav(filepath, sr=sr,min_dur_sec=min_dur_sec)
    #linear_spect = lin_spectogram_from_wav(audio_data, hop_length, win_length, n_mels)
    linear_spect = lin_spectogram_from_wav(audio_data, hop_length, win_length, n_fft=512)
    mag, _ = librosa.magphase(linear_spect)  # magnitude
    mag_T = mag.T
    
    if mode=='train':
        randtime = np.random.randint(0, mag_T.shape[1]-spec_len)
        spec_mag = mag_T[:, randtime:randtime+spec_len]
    else:
        spec_mag = mag_T
    
    # preprocessing, subtract mean, divided by time-wise var
    mu = np.mean(spec_mag, 0, keepdims=True)
    std = np.std(spec_mag, 0, keepdims=True)
    return (spec_mag - mu) / (std + 1e-5)
    


def load_npy_data(filepath,spec_len=400,mode='train'):
    mag_T = np.load(filepath)
    if mode=='train':
        randtime = np.random.randint(0, mag_T.shape[1]-spec_len)
        spec_mag = mag_T[:, randtime:randtime+spec_len]
    else:
        spec_mag = mag_T
    return spec_mag
    
    



def speech_collate(batch):
    targets = []
    specs = []
    for sample in batch:
        specs.append(sample['features'])
        targets.append((sample['labels']))
    return specs, targets

# %% [markdown]
# ## SpeechDataGenerator

# %%
class SpeechDataGenerator():
    """Speech dataset."""

    def __init__(self, manifest, mode):
        """
        Read the textfile and get the paths
        """
        
        # [line.rstrip('\n').split(' ')[0]
        self.mode=mode
        self.audio_links = [" ".join(line.rstrip('\n').split(' ')[:-1]) for line in open(manifest)]
        self.labels = [int(line.rstrip('\n').split(' ')[-1]) for line in open(manifest)]
        

    def __len__(self):
        return len(self.audio_links)

    def __getitem__(self, idx):
        audio_link =self.audio_links[idx]
        class_id = self.labels[idx]
        #lang_label=lang_id[self.audio_links[idx].split('/')[-2]]
        spec = load_data(audio_link,mode=self.mode)
        sample = {'features': torch.from_numpy(np.ascontiguousarray(spec)), 'labels': torch.from_numpy(np.ascontiguousarray(class_id))}
        return sample

# %% [markdown]
# ## Train X Vector

# %%
torch.multiprocessing.set_sharing_strategy('file_system')

########## Argument parser

training_filepath = '/content/drive/My Drive/10_lang_wav_files/train_10_lang.txt'
testing_filepath = '/content/drive/My Drive/10_lang_wav_files/test_10_lang.txt'
validation_filepath = '/content/drive/My Drive/10_lang_wav_files/validation_10_lang.txt'
input_dim = 257
num_classes = 10
lamda_val = 0.5
batch_size = 100
use_gpu = True
num_epochs = 100
# parser = argparse.ArgumentParser(add_help=False)
# parser.add_argument('-training_filepath', type=str, default='/content/drive/My Drive/meta/training.txt')
# parser.add_argument('-testing_filepath', type=str, default='/content/drive/My Drive/meta/testing.txt')
# parser.add_argument('-validation_filepath', type=str, default='/content/drive/My Drive/meta/validation.txt')

# parser.add_argument('-input_dim', action="store_true", default=257)
# parser.add_argument('-num_classes', action="store_true", default=9)
# parser.add_argument('-lamda_val', action="store_true", default=0.5)
# parser.add_argument('-batch_size', action="store_true", default=10)
# parser.add_argument('-use_gpu', action="store_true", default=True)
# parser.add_argument('-num_epochs', action="store_true", default=30)
#args = parser.parse_args()

### Data related
dataset_train = SpeechDataGenerator(manifest=training_filepath, mode='train')
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=speech_collate)

dataset_val = SpeechDataGenerator(manifest=validation_filepath, mode='train')
dataloader_val = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=speech_collate)

dataset_test = SpeechDataGenerator(manifest=testing_filepath, mode='test')
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=True, collate_fn=speech_collate)

## Model related
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = X_vector(input_dim, num_classes).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0, betas=(0.9, 0.98), eps=1e-9)
loss_fun = nn.CrossEntropyLoss()


def train(dataloader_train, epoch):
    train_loss_list = []
    full_preds = []
    full_gts = []
    model.train()

    for i_batch, sample_batched in enumerate(dataloader_train):
        print("batch: " + str(i_batch+1))
        features = torch.from_numpy(np.asarray([torch_tensor.numpy().T for torch_tensor in sample_batched[0]])).float()
        labels = torch.from_numpy(np.asarray([torch_tensor[0].numpy() for torch_tensor in sample_batched[1]]))
        labels = labels.long()
        features, labels = features.to(device), labels.to(device)
        features.requires_grad = True
        optimizer.zero_grad()
        pred_logits, x_vec = model(features)
        #### CE loss
        loss = loss_fun(pred_logits, labels)
        loss.backward()
        optimizer.step()
        train_loss_list.append(loss.item())
        # train_acc_list.append(accuracy)
        # if i_batch%10==0:
        #    print('Loss {} after {} iteration'.format(np.mean(np.asarray(train_loss_list)),i_batch))

        predictions = np.argmax(pred_logits.detach().cpu().numpy(), axis=1)
        for pred in predictions:
            full_preds.append(pred)
        for lab in labels.detach().cpu().numpy():
            full_gts.append(lab)

    mean_acc = accuracy_score(full_gts, full_preds)
    mean_loss = np.mean(np.asarray(train_loss_list))
    print('Total training loss {} and training Accuracy {} after {} epochs'.format(mean_loss, mean_acc, epoch))


def validation(dataloader_val, epoch):
    model.eval()
    with torch.no_grad():
        val_loss_list = []
        full_preds = []
        full_gts = []
        for i_batch, sample_batched in enumerate(dataloader_val):
            features = torch.from_numpy(
                np.asarray([torch_tensor.numpy().T for torch_tensor in sample_batched[0]])).float()
            labels = torch.from_numpy(np.asarray([torch_tensor[0].numpy() for torch_tensor in sample_batched[1]]))
            labels = labels.long()
            features, labels = features.to(device), labels.to(device)
            pred_logits, x_vec = model(features)
            #### CE loss
            loss = loss_fun(pred_logits, labels)
            val_loss_list.append(loss.item())
            # train_acc_list.append(accuracy)
            predictions = np.argmax(pred_logits.detach().cpu().numpy(), axis=1)
            for pred in predictions:
                full_preds.append(pred)
            for lab in labels.detach().cpu().numpy():
                full_gts.append(lab)

        mean_acc = accuracy_score(full_gts, full_preds)
        mean_loss = np.mean(np.asarray(val_loss_list))
        print('Total validation loss {} and Validation accuracy {} after {} epochs'.format(mean_loss, mean_acc, epoch))

        # TODO: CHANGE BACK TO SAVE MODEL:
        # model_save_path = os.path.join('save_model', 'best_check_point_' + str(epoch) + '_' + str(mean_loss))
        # state_dict = {'model': model.state_dict(), 'optimizer': optimizer.state_dict(), 'epoch': epoch}
        # torch.save(state_dict, model_save_path)

# %%
for epoch in range(num_epochs):
    print(epoch+1)
    train(dataloader_train, epoch)
    validation(dataloader_val, epoch)
# Out:
# 1
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 2.234132787159511 and training Accuracy 0.15050215208034434 after 0 epochs
# Total validation loss 2.2177488940102714 and Validation accuracy 0.18981348637015782 after 0 epochs
# 2
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 2.0926509772028243 and training Accuracy 0.2266857962697274 after 1 epochs
# Total validation loss 2.1029230764933993 and Validation accuracy 0.22008608321377332 after 1 epochs
# 3
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.9839067578315734 and training Accuracy 0.27015781922525106 after 2 epochs
# Total validation loss 2.1383572476250783 and Validation accuracy 0.19483500717360114 after 2 epochs
# 4
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.865819994040898 and training Accuracy 0.3413199426111908 after 3 epochs
# Total validation loss 1.9016808594976153 and Validation accuracy 0.3124820659971306 after 3 epochs
# 5
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.735347649029323 and training Accuracy 0.39612625538020085 after 4 epochs
# Total validation loss 1.8694815771920341 and Validation accuracy 0.32309899569583933 after 4 epochs
# 6
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.6220177360943386 and training Accuracy 0.4292682926829268 after 5 epochs
# Total validation loss 1.7796018310955593 and Validation accuracy 0.3652797704447633 after 5 epochs
# 7
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.5316455943243845 and training Accuracy 0.47403156384505024 after 6 epochs
# Total validation loss 1.7180878724370683 and Validation accuracy 0.39354375896700144 after 6 epochs
# 8
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.4471679363931929 and training Accuracy 0.5100430416068866 after 7 epochs
# Total validation loss 1.4772046072142464 and Validation accuracy 0.4886657101865136 after 7 epochs
# 9
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.331237028326307 and training Accuracy 0.5536585365853659 after 8 epochs
# Total validation loss 1.4979803119386945 and Validation accuracy 0.5007173601147776 after 8 epochs
# 10
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.2823246359825133 and training Accuracy 0.5850789096126255 after 9 epochs
# Total validation loss 1.4230351039341518 and Validation accuracy 0.5232424677187948 after 9 epochs
# 11
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.1670733162334987 and training Accuracy 0.6146341463414634 after 10 epochs
# Total validation loss 1.155423824276243 and Validation accuracy 0.6350071736011478 after 10 epochs
# 12
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.1468876779079438 and training Accuracy 0.6329985652797705 after 11 epochs
# Total validation loss 1.2047834788049971 and Validation accuracy 0.6134863701578193 after 11 epochs
# 13
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.0557261841637748 and training Accuracy 0.6618364418938307 after 12 epochs
# Total validation loss 1.0392815266336715 and Validation accuracy 0.6619799139167862 after 12 epochs
# 14
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.9903268396854401 and training Accuracy 0.6843615494978479 after 13 epochs
# Total validation loss 1.0168258190155028 and Validation accuracy 0.687948350071736 after 13 epochs
# 15
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.9339905500411987 and training Accuracy 0.6994261119081779 after 14 epochs
# Total validation loss 0.9205091493470329 and Validation accuracy 0.6992826398852224 after 14 epochs
# 16
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.8758939376899174 and training Accuracy 0.7199426111908178 after 15 epochs
# Total validation loss 0.9664124897548131 and Validation accuracy 0.6921090387374462 after 15 epochs
# 17
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.837477684872491 and training Accuracy 0.7355810616929699 after 16 epochs
# Total validation loss 0.8505452454090119 and Validation accuracy 0.7450502152080344 after 16 epochs
# 18
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.8079388184206826 and training Accuracy 0.748493543758967 after 17 epochs
# Total validation loss 0.770657776083265 and Validation accuracy 0.7596843615494978 after 17 epochs
# 19
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7541055883680071 and training Accuracy 0.7631276901004305 after 18 epochs
# Total validation loss 0.7358414513724191 and Validation accuracy 0.7892395982783357 after 18 epochs
# 20
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7544901703085218 and training Accuracy 0.7618364418938307 after 19 epochs
# Total validation loss 0.7780998813254493 and Validation accuracy 0.7615494978479197 after 19 epochs
# 21
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6608202597924642 and training Accuracy 0.7870875179340029 after 20 epochs
# Total validation loss 0.6532832213810512 and Validation accuracy 0.8021520803443328 after 20 epochs
# 22
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.707767470393862 and training Accuracy 0.781635581061693 after 21 epochs
# Total validation loss 0.7009558179548808 and Validation accuracy 0.7802008608321377 after 21 epochs
# 23
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6062813196863447 and training Accuracy 0.8064562410329985 after 22 epochs
# Total validation loss 0.6035455827202115 and Validation accuracy 0.824103299856528 after 22 epochs
# 24
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6140954571110862 and training Accuracy 0.8073170731707318 after 23 epochs
# Total validation loss 0.6423474873815264 and Validation accuracy 0.8061692969870875 after 23 epochs
# 25
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6001173172678266 and training Accuracy 0.8094691535150645 after 24 epochs
# Total validation loss 0.6088924314294543 and Validation accuracy 0.8047345767575322 after 24 epochs
# 26
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5452999012810843 and training Accuracy 0.8262553802008609 after 25 epochs
# Total validation loss 0.6285197828497205 and Validation accuracy 0.8018651362984218 after 25 epochs
# 27
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5682180540902274 and training Accuracy 0.8235294117647058 after 26 epochs
# Total validation loss 0.5517828805106026 and Validation accuracy 0.833142037302726 after 26 epochs
# 28
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5333990803786687 and training Accuracy 0.8317073170731707 after 27 epochs
# Total validation loss 0.4517892394747053 and Validation accuracy 0.8754662840746055 after 27 epochs
# 29
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4808677847896303 and training Accuracy 0.8464849354375896 after 28 epochs
# Total validation loss 0.48961265342576166 and Validation accuracy 0.8552367288378766 after 28 epochs
# 30
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.523120606797082 and training Accuracy 0.8371592539454806 after 29 epochs
# Total validation loss 0.43385582097939085 and Validation accuracy 0.8803443328550933 after 29 epochs
# 31
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.47085597770554677 and training Accuracy 0.8569583931133429 after 30 epochs
# Total validation loss 0.4308542272874287 and Validation accuracy 0.8767575322812051 after 30 epochs
# 32
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4796715463910784 and training Accuracy 0.8527977044476327 after 31 epochs
# Total validation loss 0.5132821444954191 and Validation accuracy 0.8430416068866571 after 31 epochs
# 33
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.42640126602990286 and training Accuracy 0.8661406025824964 after 32 epochs
# Total validation loss 0.42320522793701715 and Validation accuracy 0.8830703012912482 after 32 epochs
# 34
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4249765253492764 and training Accuracy 0.8667144906743185 after 33 epochs
# Total validation loss 0.3672074039067541 and Validation accuracy 0.8919655667144907 after 33 epochs
# 35
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.44526700313602174 and training Accuracy 0.8652797704447632 after 34 epochs
# Total validation loss 0.3632431866867202 and Validation accuracy 0.8975609756097561 after 34 epochs
# 36
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.38359658611672265 and training Accuracy 0.8803443328550933 after 35 epochs
# Total validation loss 0.42534976473876407 and Validation accuracy 0.8700143472022955 after 35 epochs
# 37
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.41508612207004003 and training Accuracy 0.8769010043041607 after 36 epochs
# Total validation loss 0.4093158743211201 and Validation accuracy 0.8899569583931134 after 36 epochs
# 38
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.38874228830848423 and training Accuracy 0.8806312769010043 after 37 epochs
# Total validation loss 0.31177487181765695 and Validation accuracy 0.9110473457675753 after 37 epochs
# 39
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.37445506559950964 and training Accuracy 0.8860832137733142 after 38 epochs
# Total validation loss 0.35076045777116505 and Validation accuracy 0.900286944045911 after 38 epochs
# 40
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.36476131209305357 and training Accuracy 0.8918220946915352 after 39 epochs
# Total validation loss 0.3566613210099084 and Validation accuracy 0.9067431850789096 after 39 epochs
# 41
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3675738030246326 and training Accuracy 0.8850789096126256 after 40 epochs
# Total validation loss 0.34545113146305084 and Validation accuracy 0.8995695839311334 after 40 epochs
# 42
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.33812525123357773 and training Accuracy 0.9007173601147777 after 41 epochs
# Total validation loss 0.32549681386777335 and Validation accuracy 0.9167862266857962 after 41 epochs
# 43
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3366625119532858 and training Accuracy 0.8975609756097561 after 42 epochs
# Total validation loss 0.36403854191303253 and Validation accuracy 0.896700143472023 after 42 epochs
# 44
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.35213939994573595 and training Accuracy 0.8954088952654232 after 43 epochs
# Total validation loss 0.2700426505080291 and Validation accuracy 0.933428981348637 after 43 epochs
# 45
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3440800183585712 and training Accuracy 0.8992826398852224 after 44 epochs
# Total validation loss 0.2530314752033779 and Validation accuracy 0.9324246771879483 after 44 epochs
# 46
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3222969590553216 and training Accuracy 0.9063127690100431 after 45 epochs
# Total validation loss 0.3023043102451733 and Validation accuracy 0.9196556671449068 after 45 epochs
# 47
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3118549679006849 and training Accuracy 0.9041606886657102 after 46 epochs
# Total validation loss 0.2599010461143085 and Validation accuracy 0.9282639885222381 after 46 epochs
# 48
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3366254804389817 and training Accuracy 0.9027259684361549 after 47 epochs
# Total validation loss 0.2952563183648246 and Validation accuracy 0.9255380200860832 after 47 epochs
# 49
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.2787023574113846 and training Accuracy 0.921090387374462 after 48 epochs
# Total validation loss 0.18813800609537534 and Validation accuracy 0.9532281205164993 after 48 epochs
# 50
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.34079338908195494 and training Accuracy 0.9004304160688665 after 49 epochs
# Total validation loss 0.27517796478101186 and Validation accuracy 0.9219512195121952 after 49 epochs
# 51
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33

# %% [markdown]
# ## Data Generator

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import os
import shutil
import numpy as np
import random
import librosa
import soundfile as sf
from pydub import AudioSegment
from pydub.silence import split_on_silence
from concurrent.futures import ThreadPoolExecutor

# %%
def duplicate_files_and_folders(source_root, destination_root):
    for root, dirs, files in os.walk(source_root):
        # Get the relative path from the source root
        relative_path = os.path.relpath(root, source_root)

        # Create the destination directory path
        destination_dir = os.path.join(destination_root, relative_path)

        # Create the destination directory if it doesn't exist
        os.makedirs(destination_dir, exist_ok=True)

        # Copy files to the destination directory
        for file in files:
            source_file = os.path.join(root, file)
            destination_file = os.path.join(destination_dir, file)
            shutil.copy2(source_file, destination_file)

        # Duplicate subfolders recursively
        for subdir in dirs:
            source_subdir = os.path.join(root, subdir)
            destination_subdir = os.path.join(destination_dir, subdir)
            duplicate_files_and_folders(source_subdir, destination_subdir)


def transform_audio(audio_data, sr, n_steps=None, noise_mean=0., noise_std=None, speed_rate=None):
    if n_steps is not None:
        audio_data = librosa.effects.pitch_shift(audio_data, sr=sr, n_steps=n_steps)
    if noise_std is not None:
        noise = np.random.normal(noise_mean, noise_std, audio_data.shape)
        audio_data = np.clip(audio_data + noise, -1., 1.)
    if speed_rate is not None:
        audio_data = librosa.effects.time_stretch(audio_data, rate=speed_rate)
    return audio_data

# reduce noise and transform to wav together.
def reduce_noise(audio_file_path):
    audio_file = AudioSegment.from_wav(audio_file_path)
    chunks = split_on_silence(audio_file, min_silence_len=1000, silence_thresh=-20)
    selected_chunks = [chunk for chunk in chunks if len(chunk) > 0]

    # Check if selected_chunks is empty
    if not selected_chunks:
        # print(f"No non-silent chunks found in {audio_file_path}. No noise reduction applied.")
        return

    new_audio = selected_chunks[0]
    for chunk in selected_chunks[1:]:
        new_audio += chunk
    new_audio.export(audio_file_path, format='wav')

def convert_mp3_to_wav(audio_file_path, output_path):
    audio = AudioSegment.from_file(audio_file_path)
    output_file_path = output_path.replace(".mp3", ".wav")
    audio.export(output_file_path, format="wav")
    return output_file_path

def convert_transform_and_reduce_noise(file_path, apply_transformations):
    # Convert to WAV
    sound = AudioSegment.from_mp3(file_path)
    fname_without_ext = os.path.splitext(file_path)[0]
    wav_path = f"{fname_without_ext}.wav"
    sound.export(wav_path, format="wav")
    os.remove(file_path)  # delete original file

    # Reduce noise
    reduce_noise(wav_path)

    # Load WAV and transform audio if apply_transformations is True
    if apply_transformations:
        audio_data, sr = librosa.load(wav_path, sr=None)

        random_float = round(random.uniform(0.0001, 0.005), 4)
        audio_data_transformed_noise = transform_audio(
            audio_data, sr, n_steps=0, noise_mean=0., noise_std=random_float, speed_rate=1
        )
        output_filename = f"{fname_without_ext}_noise_{random_float}.wav"
        sf.write(output_filename, audio_data_transformed_noise, sr)

        random_float = round(random.uniform(1.0, 1.6), 2)
        audio_data_transformed_speed = transform_audio(
            audio_data, sr, n_steps=0, noise_mean=0., noise_std=0.00, speed_rate=random_float
        )
        output_filename = f"{fname_without_ext}_speed_{random_float}.wav"
        sf.write(output_filename, audio_data_transformed_speed, sr)

        random_float = round(random.uniform(1.0, 3.0), 2)
        audio_data_transformed_pitch = transform_audio(
            audio_data, sr, n_steps=random_float, noise_mean=0., noise_std=0.00, speed_rate=1
        )
        output_filename = f"{fname_without_ext}_pitch_{random_float}.wav"
        sf.write(output_filename, audio_data_transformed_pitch, sr)

        random_float = round(random.uniform(0.0001, 0.005), 4)
        random_float1 = round(random.uniform(1.0, 1.6), 2)
        random_float2 = round(random.uniform(1.0, 3.0), 2)
        audio_data_transformed_all = transform_audio(
            audio_data, sr, n_steps=random_float, noise_mean=0., noise_std=random_float1, speed_rate=random_float2
        )
        output_filename = f"{fname_without_ext}_noise_{random_float}_speed_{random_float1}_pitch_{random_float2}.wav"
        sf.write(output_filename, audio_data_transformed_all, sr)

    return 1

def load_basic_data(rootdir):
    counter = 0
    mp3_files = []
    for dirName, subdirList, fileList in os.walk(rootdir):
        print(f'Found directory: {dirName}')
        for fname in fileList:
            if fname.endswith('.mp3'):
                mp3_files.append((os.path.join(dirName, fname), 'train' in dirName.lower()))


def load(rootdir):
    counter = 0
    mp3_files = []
    for dirName, subdirList, fileList in os.walk(rootdir):
        print(f'Found directory: {dirName}')
        for fname in fileList:
            if fname.endswith('.mp3'):
                mp3_files.append((os.path.join(dirName, fname), 'train' in dirName.lower()))

    with ThreadPoolExecutor() as executor:
        results = executor.map(lambda params: convert_transform_and_reduce_noise(*params), mp3_files)
        counter = sum(results)

    print('=============================')
    print(f'Total Data files loaded: {counter}')
    print('=============================')

# %%
source_root = '/content/drive/My Drive/10_languages_media'
destination_root = '/content/drive/My Drive/10_languages_media_reduce_noise'

duplicate_files_and_folders(source_root, destination_root)

# %%
    rootDir = 'C:\\Users\\koazg\\Desktop\\same_size_lang'
    load(rootDir)

# %% [markdown]
# Files to path

# %%
def create_path_files(root_folder, output_folder):
    train_file = os.path.join(output_folder, 'train.txt')
    test_file = os.path.join(output_folder, 'test.txt')
    validation_file = os.path.join(output_folder, 'validation.txt')

    train_subfolders = []
    test_subfolders = []
    validation_subfolders = []
    counter_label = 0

    for folder_lang in os.listdir(root_folder):
        sub_folder = os.path.join(root_folder, folder_lang)
        if os.path.isdir(sub_folder):

            for subsub_folder in os.listdir(sub_folder):
                subsub_folder_path = os.path.join(sub_folder, subsub_folder)
                if os.path.isdir(subsub_folder_path):

                    if subsub_folder == 'Train':
                        for root, _, files in os.walk(subsub_folder_path):
                            for file in files:
                                file_path = os.path.join(root, file)
                                path_label = file_path + ' ' + str(counter_label)
                                train_subfolders.append(path_label)
                    elif subsub_folder == 'Test':
                        for root, _, files in os.walk(subsub_folder_path):
                            for file in files:
                                file_path = os.path.join(root, file)
                                path_label = file_path + ' ' + str(counter_label)
                                test_subfolders.append(path_label)
                    elif subsub_folder == 'Validation':
                        for root, _, files in os.walk(subsub_folder_path):
                            for file in files:
                                file_path = os.path.join(root, file)
                                path_label = file_path + ' ' + str(counter_label)
                                validation_subfolders.append(path_label)
        counter_label += 1

    with open(train_file, 'w') as file:
        file.write('\n'.join(train_subfolders))

    with open(test_file, 'w') as file:
        file.write('\n'.join(test_subfolders))

    with open(validation_file, 'w') as file:
        file.write('\n'.join(validation_subfolders))

    print("======================================")
    print("Txt files updated successfully!")
    print(f'Total labels : {counter_label}')
    print("======================================")

# %%
root_folder_path = '/content/drive/My Drive/10_lang_reupload'
output_folder_path = '/content/drive/My Drive/10_lang_reupload'
create_path_files(root_folder_path, output_folder_path)
# Out:
# ======================================
# Txt files updated successfully!
# Total labels : 10
# ======================================
