# %% [markdown]
# # **Model Version: 0.1**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### ***Imports***

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
import os
import numpy as np
import librosa
import random
from torch.utils.data import DataLoader
from torch import optim
import argparse
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **Models**

# %%
class TDNN(nn.Module):
    
    def __init__(
                    self, 
                    input_dim=23, 
                    output_dim=512,
                    context_size=5,
                    stride=1,
                    dilation=1,
                    batch_norm=False,
                    dropout_p=0.2
                ):
        '''
        TDNN as defined by https://www.danielpovey.com/files/2015_interspeech_multisplice.pdf

        Affine transformation not applied globally to all frames but smaller windows with local context

        batch_norm: True to include batch normalisation after the non linearity
        
        Context size and dilation determine the frames selected
        (although context size is not really defined in the traditional sense)
        For example:
            context size 5 and dilation 1 is equivalent to [-2,-1,0,1,2]
            context size 3 and dilation 2 is equivalent to [-2, 0, 2]
            context size 1 and dilation 1 is equivalent to [0]
        '''
        super(TDNN, self).__init__()
        self.context_size = context_size
        self.stride = stride
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.dilation = dilation
        self.dropout_p = dropout_p
        self.batch_norm = batch_norm
      
        self.kernel = nn.Linear(input_dim*context_size, output_dim)
        self.nonlinearity = nn.ReLU()
        if self.batch_norm:
            self.bn = nn.BatchNorm1d(output_dim)
        if self.dropout_p:
            self.drop = nn.Dropout(p=self.dropout_p)
        
    def forward(self, x):
        '''
        input: size (batch, seq_len, input_features)
        outpu: size (batch, new_seq_len, output_features)
        '''
        
        _, _, d = x.shape
        assert (d == self.input_dim), 'Input dimension was wrong. Expected ({}), got ({})'.format(self.input_dim, d)
        x = x.unsqueeze(1)

        # Unfold input into smaller temporal contexts
        x = F.unfold(
                        x, 
                        (self.context_size, self.input_dim), 
                        stride=(1,self.input_dim), 
                        dilation=(self.dilation,1)
                    )

        # N, output_dim*context_size, new_t = x.shape
        x = x.transpose(1,2)
        x = self.kernel(x.float())
        x = self.nonlinearity(x)
        
        if self.dropout_p:
            x = self.drop(x)

        if self.batch_norm:
            x = x.transpose(1,2)
            x = self.bn(x)
            x = x.transpose(1,2)

        return x

# %%
class X_vector(nn.Module):
    def __init__(self, input_dim = 40, num_classes=10):
        super(X_vector, self).__init__()
        self.tdnn1 = TDNN(input_dim=input_dim, output_dim=512, context_size=5, dilation=1,dropout_p=0.5)
        # trying to add a new layer
        self.tdnn2 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn3 = TDNN(input_dim=512, output_dim=512, context_size=3, dilation=1,dropout_p=0.5)
         # trying to add a new layer
        self.tdnn4 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn5 = TDNN(input_dim=512, output_dim=512, context_size=2, dilation=2,dropout_p=0.5)
        self.tdnn6 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn7 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=3,dropout_p=0.5)
        #### Frame levelPooling
        self.segment8 = nn.Linear(1024, 512)
        self.segment9 = nn.Linear(512, 512)
        self.output = nn.Linear(512, num_classes)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, inputs):
        tdnn1_out = self.tdnn1(inputs)
        return tdnn1_out
        tdnn2_out = self.tdnn2(tdnn1_out)
        tdnn3_out = self.tdnn3(tdnn2_out)
        tdnn4_out = self.tdnn4(tdnn3_out)
        tdnn5_out = self.tdnn5(tdnn4_out)
        # 2 new rows because of the new layers
        tdnn6_out = self.tdnn6(tdnn5_out)
        tdnn7_out = self.tdnn7(tdnn6_out)
        ### Stat Pool

        # mean = torch.mean(tdnn5_out,1)
        # std = torch.std(tdnn5_out,1)
        mean = torch.mean(tdnn7_out,1)
        std = torch.std(tdnn7_out,1)

        stat_pooling = torch.cat((mean,std),1)

        # segment6_out = self.segment6(stat_pooling)
        # x_vec = self.segment7(segment6_out)
        segment8_out = self.segment8(stat_pooling)
        x_vec = self.segment9(segment8_out)

        predictions = self.softmax(self.output(x_vec))
        return predictions,x_vec

# %%
class X_vector(nn.Module):
    def __init__(self, input_dim = 40, num_classes=10):
        super(X_vector, self).__init__()
        self.tdnn1 = TDNN(input_dim=input_dim, output_dim=512, context_size=5, dilation=1,dropout_p=0.5)
        # trying to add a new layer
        self.tdnn2 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn3 = TDNN(input_dim=512, output_dim=512, context_size=3, dilation=1,dropout_p=0.5)
         # trying to add a new layer
        self.tdnn4 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn5 = TDNN(input_dim=512, output_dim=512, context_size=2, dilation=2,dropout_p=0.5)
        self.tdnn6 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=1,dropout_p=0.5)
        self.tdnn7 = TDNN(input_dim=512, output_dim=512, context_size=1, dilation=3,dropout_p=0.5)
        #### Frame levelPooling
        self.segment8 = nn.Linear(1024, 512)
        self.segment9 = nn.Linear(512, 512)
        self.output = nn.Linear(512, num_classes)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, inputs):
        tdnn1_out = self.tdnn1(inputs)
        tdnn2_out = self.tdnn2(tdnn1_out)
        tdnn3_out = self.tdnn3(tdnn2_out)
        tdnn4_out = self.tdnn4(tdnn3_out)
        tdnn5_out = self.tdnn5(tdnn4_out)
        tdnn6_out = self.tdnn6(tdnn5_out)
        tdnn7_out = self.tdnn7(tdnn6_out)
        ### Stat Pool
        
       # mean = torch.mean(tdnn5_out,1)
        # std = torch.std(tdnn5_out,1)
        mean = torch.mean(tdnn7_out,1)
        std = torch.std(tdnn7_out,1)

        stat_pooling = torch.cat((mean,std),1)

        # segment6_out = self.segment6(stat_pooling)
        # x_vec = self.segment7(segment6_out)
        segment8_out = self.segment8(stat_pooling)
        x_vec = self.segment9(segment8_out)
        
        predictions = self.output(x_vec)
        return predictions,x_vec

# %% [markdown]
# ### Utiles

# %%
def load_wav(audio_filepath, sr, min_dur_sec=4):
    audio_data,fs  = librosa.load(audio_filepath,sr=16000)
    len_file = len(audio_data)
    
    if len_file <int(min_dur_sec*sr):
        dummy=np.zeros((1,int(min_dur_sec*sr)-len_file))
        extened_wav = np.concatenate((audio_data,dummy[0]))
    else:
        
        extened_wav = audio_data
    return extened_wav


def lin_mel_from_wav(wav, hop_length, win_length, n_mels):
    linear = librosa.feature.melspectrogram(wav, n_mels=n_mels, win_length=win_length, hop_length=hop_length) # linear spectrogram
    return linear.T

def lin_spectogram_from_wav(wav, hop_length, win_length, n_fft=512):
    linear = librosa.stft(wav, n_fft=n_fft, win_length=win_length, hop_length=hop_length) # linear spectrogram
    return linear.T


def feature_extraction(filepath,sr=16000, min_dur_sec=4,win_length=400,hop_length=160, n_mels=40, spec_len=400,mode='train'):
    audio_data = load_wav(filepath, sr=sr,min_dur_sec=min_dur_sec)
    linear_spect = lin_spectogram_from_wav(audio_data, hop_length, win_length, n_fft=512)
    mag, _ = librosa.magphase(linear_spect)  # magnitude
    mag_T = mag.T
    mu = np.mean(mag_T, 0, keepdims=True)
    std = np.std(mag_T, 0, keepdims=True)
    return (mag_T - mu) / (std + 1e-5)
    
    
    
    
def load_data(filepath,sr=16000, min_dur_sec=4,win_length=400,hop_length=160, n_mels=40, spec_len=400,mode='train'):
    audio_data = load_wav(filepath, sr=sr,min_dur_sec=min_dur_sec)
    #linear_spect = lin_spectogram_from_wav(audio_data, hop_length, win_length, n_mels)
    linear_spect = lin_spectogram_from_wav(audio_data, hop_length, win_length, n_fft=512)
    mag, _ = librosa.magphase(linear_spect)  # magnitude
    mag_T = mag.T
    
    if mode=='train':
        randtime = np.random.randint(0, mag_T.shape[1]-spec_len)
        spec_mag = mag_T[:, randtime:randtime+spec_len]
    else:
        spec_mag = mag_T
    
    # preprocessing, subtract mean, divided by time-wise var
    mu = np.mean(spec_mag, 0, keepdims=True)
    std = np.std(spec_mag, 0, keepdims=True)
    return (spec_mag - mu) / (std + 1e-5)
    


def load_npy_data(filepath,spec_len=400,mode='train'):
    mag_T = np.load(filepath)
    if mode=='train':
        randtime = np.random.randint(0, mag_T.shape[1]-spec_len)
        spec_mag = mag_T[:, randtime:randtime+spec_len]
    else:
        spec_mag = mag_T
    return spec_mag
    
    



def speech_collate(batch):
    targets = []
    specs = []
    for sample in batch:
        specs.append(sample['features'])
        targets.append((sample['labels']))
    return specs, targets

# %% [markdown]
# ## SpeechDataGenerator

# %%
class SpeechDataGenerator():
    """Speech dataset."""

    def __init__(self, manifest, mode):
        """
        Read the textfile and get the paths
        """
        
        # [line.rstrip('\n').split(' ')[0]
        self.mode=mode
        self.audio_links = [" ".join(line.rstrip('\n').split(' ')[:-1]) for line in open(manifest)]
        self.labels = [int(line.rstrip('\n').split(' ')[-1]) for line in open(manifest)]
        

    def __len__(self):
        return len(self.audio_links)

    def __getitem__(self, idx):
        audio_link =self.audio_links[idx]
        class_id = self.labels[idx]
        #lang_label=lang_id[self.audio_links[idx].split('/')[-2]]
        spec = load_data(audio_link,mode=self.mode)
        sample = {'features': torch.from_numpy(np.ascontiguousarray(spec)), 'labels': torch.from_numpy(np.ascontiguousarray(class_id))}
        return sample

# %% [markdown]
# ## Train X Vector

# %%
torch.multiprocessing.set_sharing_strategy('file_system')

########## Argument parser

# training_filepath = '/content/drive/My Drive/meta/training.txt'
# testing_filepath = '/content/drive/My Drive/meta/testing.txt'
# validation_filepath = '/content/drive/My Drive/meta/validation.txt'
training_filepath = '/content/drive/My Drive/10_lang_wav_files/train_10_lang.txt'
testing_filepath = '/content/drive/My Drive/10_lang_wav_files/test_10_lang.txt'
validation_filepath = '/content/drive/My Drive/10_lang_wav_files/validation_10_lang.txt'
input_dim = 257
num_classes = 10
lamda_val = 0.5
batch_size = 100
use_gpu = True
num_epochs = 100
# parser = argparse.ArgumentParser(add_help=False)
# parser.add_argument('-training_filepath', type=str, default='/content/drive/My Drive/meta/training.txt')
# parser.add_argument('-testing_filepath', type=str, default='/content/drive/My Drive/meta/testing.txt')
# parser.add_argument('-validation_filepath', type=str, default='/content/drive/My Drive/meta/validation.txt')

# parser.add_argument('-input_dim', action="store_true", default=257)
# parser.add_argument('-num_classes', action="store_true", default=9)
# parser.add_argument('-lamda_val', action="store_true", default=0.5)
# parser.add_argument('-batch_size', action="store_true", default=10)
# parser.add_argument('-use_gpu', action="store_true", default=True)
# parser.add_argument('-num_epochs', action="store_true", default=30)
#args = parser.parse_args()

### Data related
dataset_train = SpeechDataGenerator(manifest=training_filepath, mode='train')
dataloader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=speech_collate)

dataset_val = SpeechDataGenerator(manifest=validation_filepath, mode='train')
dataloader_val = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, collate_fn=speech_collate)

dataset_test = SpeechDataGenerator(manifest=testing_filepath, mode='test')
dataloader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=True, collate_fn=speech_collate)

## Model related
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = X_vector(input_dim, num_classes).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0, betas=(0.9, 0.98), eps=1e-9)
loss_fun = nn.CrossEntropyLoss()


def train(dataloader_train, epoch):
    train_loss_list = []
    full_preds = []
    full_gts = []
    model.train()

    for i_batch, sample_batched in enumerate(dataloader_train):
        print("batch: " + str(i_batch+1))
        features = torch.from_numpy(np.asarray([torch_tensor.numpy().T for torch_tensor in sample_batched[0]])).float()
        labels = torch.from_numpy(np.asarray([torch_tensor[0].numpy() for torch_tensor in sample_batched[1]]))
        labels = labels.long()
        features, labels = features.to(device), labels.to(device)
        features.requires_grad = True
        optimizer.zero_grad()
        pred_logits, x_vec = model(features)
        #### CE loss
        loss = loss_fun(pred_logits, labels)
        loss.backward()
        optimizer.step()
        train_loss_list.append(loss.item())
        # train_acc_list.append(accuracy)
        # if i_batch%10==0:
        #    print('Loss {} after {} iteration'.format(np.mean(np.asarray(train_loss_list)),i_batch))

        predictions = np.argmax(pred_logits.detach().cpu().numpy(), axis=1)
        for pred in predictions:
            full_preds.append(pred)
        for lab in labels.detach().cpu().numpy():
            full_gts.append(lab)

    mean_acc = accuracy_score(full_gts, full_preds)
    mean_loss = np.mean(np.asarray(train_loss_list))
    print('Total training loss {} and training Accuracy {} after {} epochs'.format(mean_loss, mean_acc, epoch))


def validation(dataloader_val, epoch):
    model.eval()
    with torch.no_grad():
        val_loss_list = []
        full_preds = []
        full_gts = []
        for i_batch, sample_batched in enumerate(dataloader_val):
            features = torch.from_numpy(
                np.asarray([torch_tensor.numpy().T for torch_tensor in sample_batched[0]])).float()
            labels = torch.from_numpy(np.asarray([torch_tensor[0].numpy() for torch_tensor in sample_batched[1]]))
            labels = labels.long()
            features, labels = features.to(device), labels.to(device)
            pred_logits, x_vec = model(features)
            #### CE loss
            loss = loss_fun(pred_logits, labels)
            val_loss_list.append(loss.item())
            # train_acc_list.append(accuracy)
            predictions = np.argmax(pred_logits.detach().cpu().numpy(), axis=1)
            for pred in predictions:
                full_preds.append(pred)
            for lab in labels.detach().cpu().numpy():
                full_gts.append(lab)

        mean_acc = accuracy_score(full_gts, full_preds)
        mean_loss = np.mean(np.asarray(val_loss_list))
        print('Total validation loss {} and Validation accuracy {} after {} epochs'.format(mean_loss, mean_acc, epoch))

        # TODO: CHANGE BACK TO SAVE MODEL:
        # model_save_path = os.path.join('save_model', 'best_check_point_' + str(epoch) + '_' + str(mean_loss))
        # state_dict = {'model': model.state_dict(), 'optimizer': optimizer.state_dict(), 'epoch': epoch}
        # torch.save(state_dict, model_save_path)

# %%
for epoch in range(num_epochs):
    print(epoch+1)
    train(dataloader_train, epoch)
    validation(dataloader_val, epoch)
# Out:
# 1
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 2.2399639061519077 and training Accuracy 0.1351506456241033 after 0 epochs
# Total validation loss 2.307949699674334 and Validation accuracy 0.10014347202295552 after 0 epochs
# 2
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 2.1740155254091533 and training Accuracy 0.14992826398852224 after 1 epochs
# Total validation loss 2.2192368950162615 and Validation accuracy 0.13385939741750358 after 1 epochs
# 3
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 2.083688291481563 and training Accuracy 0.21420373027259684 after 2 epochs
# Total validation loss 2.1217000382287163 and Validation accuracy 0.18565279770444762 after 2 epochs
# 4
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.9811783177512032 and training Accuracy 0.2715925394548063 after 3 epochs
# Total validation loss 2.104429353986468 and Validation accuracy 0.17560975609756097 after 3 epochs
# 5
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.8879495995385307 and training Accuracy 0.306025824964132 after 4 epochs
# Total validation loss 1.9603794387408666 and Validation accuracy 0.28622668579626975 after 4 epochs
# 6
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.7970302632876805 and training Accuracy 0.3527977044476327 after 5 epochs
# Total validation loss 2.1145996332168577 and Validation accuracy 0.22697274031563844 after 5 epochs
# 7
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.7378963572638375 and training Accuracy 0.387948350071736 after 6 epochs
# Total validation loss 2.013688348020826 and Validation accuracy 0.24332855093256814 after 6 epochs
# 8
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.6465860656329563 and training Accuracy 0.4296987087517934 after 7 epochs
# Total validation loss 1.8960128545761108 and Validation accuracy 0.2731707317073171 after 7 epochs
# 9
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.5771359835352217 and training Accuracy 0.457245337159254 after 8 epochs
# Total validation loss 1.857498516355242 and Validation accuracy 0.3147776183644189 after 8 epochs
# 10
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.479637462752206 and training Accuracy 0.4977044476327116 after 9 epochs
# Total validation loss 1.8112572840281895 and Validation accuracy 0.3417503586800574 after 9 epochs
# 11
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.395393192768097 and training Accuracy 0.5269727403156385 after 10 epochs
# Total validation loss 1.7006078158106124 and Validation accuracy 0.3641319942611191 after 10 epochs
# 12
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.355583485535213 and training Accuracy 0.5367288378766141 after 11 epochs
# Total validation loss 1.5546716434615 and Validation accuracy 0.43859397417503587 after 11 epochs
# 13
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.3103452256747654 and training Accuracy 0.5540889526542324 after 12 epochs
# Total validation loss 1.624947738647461 and Validation accuracy 0.41492109038737446 after 12 epochs
# 14
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.259949940443039 and training Accuracy 0.563558106169297 after 13 epochs
# Total validation loss 1.577467407499041 and Validation accuracy 0.4245337159253946 after 13 epochs
# 15
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.1824933682169234 and training Accuracy 0.6012912482065997 after 14 epochs
# Total validation loss 1.4303752507482257 and Validation accuracy 0.4746054519368723 after 14 epochs
# 16
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.134316487823214 and training Accuracy 0.6169296987087518 after 15 epochs
# Total validation loss 1.395260179042816 and Validation accuracy 0.49684361549497846 after 15 epochs
# 17
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.1114861956664495 and training Accuracy 0.6219512195121951 after 16 epochs
# Total validation loss 1.2486546329089574 and Validation accuracy 0.5895265423242467 after 16 epochs
# 18
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.0324269311768668 and training Accuracy 0.6509325681492109 after 17 epochs
# Total validation loss 1.2232912131718228 and Validation accuracy 0.5720229555236729 after 17 epochs
# 19
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 1.0012953749724798 and training Accuracy 0.6618364418938307 after 18 epochs
# Total validation loss 1.2503200207437788 and Validation accuracy 0.5659971305595409 after 18 epochs
# 20
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.9424163120133536 and training Accuracy 0.6865136298421808 after 19 epochs
# Total validation loss 1.068997427395412 and Validation accuracy 0.6466284074605452 after 19 epochs
# 21
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.9246453668390001 and training Accuracy 0.6842180774748924 after 20 epochs
# Total validation loss 1.136584289584841 and Validation accuracy 0.6035868005738881 after 20 epochs
# 22
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.8857369772025517 and training Accuracy 0.7054519368723099 after 21 epochs
# Total validation loss 1.0619013854435513 and Validation accuracy 0.6417503586800574 after 21 epochs
# 23
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.8566778702395302 and training Accuracy 0.7119081779053085 after 22 epochs
# Total validation loss 1.0519019212041583 and Validation accuracy 0.6450502152080344 after 22 epochs
# 24
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.8023997409003122 and training Accuracy 0.7317073170731707 after 23 epochs
# Total validation loss 0.9643948325089046 and Validation accuracy 0.6727403156384505 after 23 epochs
# 25
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7898443852152143 and training Accuracy 0.7354375896700144 after 24 epochs
# Total validation loss 1.0033397223268237 and Validation accuracy 0.6625538020086084 after 24 epochs
# 26
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7775876104831696 and training Accuracy 0.7441893830703012 after 25 epochs
# Total validation loss 0.9213771649769374 and Validation accuracy 0.693974175035868 after 25 epochs
# 27
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7908263947282519 and training Accuracy 0.74519368723099 after 26 epochs
# Total validation loss 0.8843950399330684 and Validation accuracy 0.7182209469153515 after 26 epochs
# 28
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7081838646105357 and training Accuracy 0.7687230989956958 after 27 epochs
# Total validation loss 0.7759792464120048 and Validation accuracy 0.7704447632711621 after 27 epochs
# 29
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.7112120206866945 and training Accuracy 0.7651362984218077 after 28 epochs
# Total validation loss 0.7562935744013105 and Validation accuracy 0.7546628407460545 after 28 epochs
# 30
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6862909857715879 and training Accuracy 0.7714490674318508 after 29 epochs
# Total validation loss 0.9242956357342856 and Validation accuracy 0.6740315638450503 after 29 epochs
# 31
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6779349969966071 and training Accuracy 0.7744619799139167 after 30 epochs
# Total validation loss 0.9678090453147888 and Validation accuracy 0.6563845050215208 after 30 epochs
# 32
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6366688021591731 and training Accuracy 0.7915351506456241 after 31 epochs
# Total validation loss 0.7962896985667093 and Validation accuracy 0.721090387374462 after 31 epochs
# 33
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6159072233097894 and training Accuracy 0.7926829268292683 after 32 epochs
# Total validation loss 0.8065528060708728 and Validation accuracy 0.7358680057388809 after 32 epochs
# 34
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.599679132444518 and training Accuracy 0.8043041606886657 after 33 epochs
# Total validation loss 0.7941096322877067 and Validation accuracy 0.7347202295552367 after 33 epochs
# 35
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.6049541217940194 and training Accuracy 0.7988522238163558 after 34 epochs
# Total validation loss 0.9359513027327401 and Validation accuracy 0.6774748923959828 after 34 epochs
# 36
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5665176344769342 and training Accuracy 0.8163558106169297 after 35 epochs
# Total validation loss 0.6695419924599784 and Validation accuracy 0.7833572453371592 after 35 epochs
# 37
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5993014139788492 and training Accuracy 0.802725968436155 after 36 epochs
# Total validation loss 0.7857981000627791 and Validation accuracy 0.7329985652797705 after 36 epochs
# 38
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.555195449079786 and training Accuracy 0.8160688665710186 after 37 epochs
# Total validation loss 0.7320847979613713 and Validation accuracy 0.7494978479196557 after 37 epochs
# 39
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5353683203458786 and training Accuracy 0.8295552367288379 after 38 epochs
# Total validation loss 0.7626582298960004 and Validation accuracy 0.7565279770444763 after 38 epochs
# 40
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5139640063047409 and training Accuracy 0.8314203730272597 after 39 epochs
# Total validation loss 0.8133076540061406 and Validation accuracy 0.7249641319942611 after 39 epochs
# 41
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5163775946412767 and training Accuracy 0.830416068866571 after 40 epochs
# Total validation loss 0.7651733372892652 and Validation accuracy 0.7529411764705882 after 40 epochs
# 42
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5033228101474898 and training Accuracy 0.8327116212338594 after 41 epochs
# Total validation loss 0.8057673871517181 and Validation accuracy 0.7318507890961262 after 41 epochs
# 43
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.5003063235964094 and training Accuracy 0.8395982783357245 after 42 epochs
# Total validation loss 0.7078948037964957 and Validation accuracy 0.7637015781922525 after 42 epochs
# 44
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.48452734095709665 and training Accuracy 0.8404591104734577 after 43 epochs
# Total validation loss 0.6686325358492987 and Validation accuracy 0.7802008608321377 after 43 epochs
# 45
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4901410302945546 and training Accuracy 0.8406025824964132 after 44 epochs
# Total validation loss 0.719950167621885 and Validation accuracy 0.7595408895265423 after 44 epochs
# 46
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4668311361755644 and training Accuracy 0.8486370157819225 after 45 epochs
# Total validation loss 0.7507364392280579 and Validation accuracy 0.7496413199426112 after 45 epochs
# 47
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4621942935245378 and training Accuracy 0.8492109038737446 after 46 epochs
# Total validation loss 0.8780666189534324 and Validation accuracy 0.6853658536585366 after 46 epochs
# 48
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.43108978463070735 and training Accuracy 0.8602582496413199 after 47 epochs
# Total validation loss 0.6183890108551298 and Validation accuracy 0.7929698708751793 after 47 epochs
# 49
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4411124105964388 and training Accuracy 0.857245337159254 after 48 epochs
# Total validation loss 0.44327743564333233 and Validation accuracy 0.8796269727403156 after 48 epochs
# 50
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.44858989460127696 and training Accuracy 0.8562410329985652 after 49 epochs
# Total validation loss 0.6076488677944456 and Validation accuracy 0.7995695839311334 after 49 epochs
# 51
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4418038696050644 and training Accuracy 0.857532281205165 after 50 epochs
# Total validation loss 0.633981728553772 and Validation accuracy 0.793400286944046 after 50 epochs
# 52
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.403349703337465 and training Accuracy 0.8684361549497848 after 51 epochs
# Total validation loss 0.8081829586199352 and Validation accuracy 0.7351506456241033 after 51 epochs
# 53
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.43133616766759325 and training Accuracy 0.860832137733142 after 52 epochs
# Total validation loss 0.7374745207173484 and Validation accuracy 0.7535150645624104 after 52 epochs
# 54
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.408770671912602 and training Accuracy 0.8707317073170732 after 53 epochs
# Total validation loss 0.6362618663481303 and Validation accuracy 0.7842180774748924 after 53 epochs
# 55
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.40513557514974047 and training Accuracy 0.8703012912482067 after 54 epochs
# Total validation loss 0.6219142603022711 and Validation accuracy 0.7968436154949785 after 54 epochs
# 56
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4078741011875016 and training Accuracy 0.8647058823529412 after 55 epochs
# Total validation loss 0.5740494455610002 and Validation accuracy 0.8190817790530847 after 55 epochs
# 57
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.4022736012935638 and training Accuracy 0.8710186513629842 after 56 epochs
# Total validation loss 0.6836492325578417 and Validation accuracy 0.775609756097561 after 56 epochs
# 58
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.37904114893504554 and training Accuracy 0.8813486370157819 after 57 epochs
# Total validation loss 0.6358008082423892 and Validation accuracy 0.7837876614060258 after 57 epochs
# 59
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.39347003464187896 and training Accuracy 0.875896700143472 after 58 epochs
# Total validation loss 0.6218521624803544 and Validation accuracy 0.793974175035868 after 58 epochs
# 60
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.33579648307391574 and training Accuracy 0.8913916786226685 after 59 epochs
# Total validation loss 0.5087563527481896 and Validation accuracy 0.8368723098995696 after 59 epochs
# 61
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3568865096994809 and training Accuracy 0.8852223816355811 after 60 epochs
# Total validation loss 0.6987335247652872 and Validation accuracy 0.7799139167862267 after 60 epochs
# 62
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3679847981248583 and training Accuracy 0.884361549497848 after 61 epochs
# Total validation loss 0.712991269997188 and Validation accuracy 0.7626972740315638 after 61 epochs
# 63
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
# batch: 56
# batch: 57
# batch: 58
# batch: 59
# batch: 60
# batch: 61
# batch: 62
# batch: 63
# batch: 64
# batch: 65
# batch: 66
# batch: 67
# batch: 68
# batch: 69
# batch: 70
# Total training loss 0.3635125909532819 and training Accuracy 0.8802008608321378 after 62 epochs
# Total validation loss 0.609745220201356 and Validation accuracy 0.7951219512195122 after 62 epochs
# 64
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# batch: 46
# batch: 47
# batch: 48
# batch: 49
# batch: 50
# batch: 51
# batch: 52
# batch: 53
# batch: 54
# batch: 55
